# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("5_6190749518103839648.csv")

# %%
data.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
data
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# # 1. In how many cities Summer olympics is held so far.

# %%
data=pd.DataFrame(data,columns=['City']).sort_values(by=['City'],ascending=True)

# %%
data=data.groupby('City')

# %%
d=data.first()

# %%
len(d)
# Out:
# 22

# %%
data.isna().any()
# Out:
# Year          False
# City          False
# Sport         False
# Discipline    False
# Athlete       False
# Country        True
# Gender        False
# Event         False
# Medal         False
# Cities         True
# Name           True
# dtype: bool

# %% [markdown]
# # 2. Which Sport is having most number of gold medal so far?(Top 5)

# %%
pd.DataFrame(data,columns=['Sport','Medal']).sort_values(by='Medal',ascending=False)
# Out:
#                Sport   Medal
# 15582     Basketball  Silver
# 21734      Athletics  Silver
# 21843       Baseball  Silver
# 21842       Baseball  Silver
# 9245   Canoe / Kayak  Silver
# ...              ...     ...
# 23607      Athletics  Bronze
# 23608      Athletics  Bronze
# 23609      Athletics  Bronze
# 23610      Athletics  Bronze
# 31164      Wrestling  Bronze
#
# [31165 rows x 2 columns]

# %%
d1=data.groupby('Medal')

# %%
d1.get_group('Gold')
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %% [markdown]
# # 3. Which Sport is having most number of  medals so far?(Top 5)

# %%
data1
# Out:
#            Sport   Medal
# 0       Aquatics    Gold
# 1       Aquatics  Silver
# 2       Aquatics  Bronze
# 3       Aquatics    Gold
# 4       Aquatics  Silver
# ...          ...     ...
# 31160  Wrestling  Bronze
# 31161  Wrestling    Gold
# 31162  Wrestling  Silver
# 31163  Wrestling  Bronze
# 31164  Wrestling  Bronze
#
# [31165 rows x 2 columns]

# %%
data1.Sport
# Out:
# 0         Aquatics
# 1         Aquatics
# 2         Aquatics
# 3         Aquatics
# 4         Aquatics
#            ...
# 31160    Wrestling
# 31161    Wrestling
# 31162    Wrestling
# 31163    Wrestling
# 31164    Wrestling
# Name: Sport, Length: 31165, dtype: object

# %%
data1=pd.DataFrame(data,columns=['Sport','Medal']).groupby(['Sport'])

# %%
data1.first()
# Out:
#                     Medal
# Sport
# Aquatics             Gold
# Archery            Bronze
# Athletics          Bronze
# Badminton          Bronze
# Baseball           Bronze
# Basketball         Bronze
# Basque Pelota        Gold
# Boxing               Gold
# Canoe                Gold
# Canoe / Kayak      Bronze
# Cricket              Gold
# Croquet              Gold
# Cycling            Bronze
# Equestrian         Bronze
# Fencing            Bronze
# Football           Bronze
# Golf               Bronze
# Gymnastics           Gold
# Handball           Bronze
# Hockey               Gold
# Ice Hockey         Bronze
# Jeu de paume       Bronze
# Judo               Bronze
# Lacrosse             Gold
# Modern Pentathlon  Bronze
# Polo               Bronze
# Rackets            Bronze
# Roque              Bronze
# Rowing             Bronze
# Rugby                Gold
# Sailing            Bronze
# Shooting           Bronze
# Skating            Bronze
# Softball           Bronze
# ...

# %%
data1.get_group('Aquatics').count()
# Out:
# Medal    4170
# dtype: int64

# %%
data1.get_group('Athletics').count()
# Out:
# Medal    3638
# dtype: int64

# %% [markdown]
# # 4. Which Player has won most number of  medals so far?(Top 5)

# %%
data1=pd.DataFrame(data,columns=['Athlete','Medal']).sort_values(by='Athlete',ascending=True).groupby(['Athlete'])

# %%
data1

# %%
data1.first()
# Out:
#                                    Medal
# Athlete
# AABYE, Edgar                        Gold
# AALTONEN, Arvo Ossian             Bronze
# AALTONEN, Paavo Johannes            Gold
# AAMODT, Ragnhild                    Gold
# AANING, Alf Lied                  Silver
# ...                                  ...
# Ã_x0096_STERVOLD, Jan Olsen         Gold
# Ã_x0096_STERVOLD, Kristian Olsen    Gold
# Ã_x0096_STERVOLD, Ole Olsen         Gold
# Ã_x0096_STMO, Ole                 Bronze
# Ã_x0096_STRAND, Per-Olof          Bronze
#
# [22762 rows x 1 columns]

# %% [markdown]
# # 5. Which Player has won most number of  gold medals so far?(Top 5)

# %%
data1=pd.DataFrame(data,columns=['Athlete','Medal']).sort_values(by='Medal',ascending=True).groupby(['Medal'])

# %%
data1.first(5)
# Out:
#                       Athlete
# Medal
# Bronze         LIDBERG, Jimmy
# Gold     MILLER, Cheryl Deann
# Silver  VANCE, Samuel Goodwin

# %% [markdown]
# # 6. In which year India has won a medal?

# %%
d1=pd.DataFrame(data,columns=['year','Medal','Country']).sort_values(by=['Country','year'],ascending=True)

# %%
d1
# Out:
#        year   Medal Country
# 28965   NaN  Bronze     AFG
# 30929   NaN  Bronze     AFG
# 19323   NaN  Silver     AHO
# 17060   NaN  Bronze     ALG
# 17064   NaN  Bronze     ALG
# ...     ...     ...     ...
# 866     NaN    Gold     ZZX
# 29603   NaN    Gold     NaN
# 31072   NaN    Gold     NaN
# 31091   NaN  Silver     NaN
# 31110   NaN  Silver     NaN
#
# [31165 rows x 3 columns]

# %% [markdown]
# # 7. Which event is popular in terms of player?(Top 5)

# %%
d1=pd.DataFrame(data,columns=['Sport','Athlete']).sort_values(by='Athlete',ascending=False)

# %%
d1
# Out:
#            Sport                   Athlete
# 8051    Aquatics  Ã_x0096_STRAND, Per-Olof
# 621     Shooting         Ã_x0096_STMO, Ole
# 608     Shooting         Ã_x0096_STMO, Ole
# 596     Shooting         Ã_x0096_STMO, Ole
# 603     Shooting         Ã_x0096_STMO, Ole
# ...          ...                       ...
# 7716  Gymnastics  AALTONEN, Paavo Johannes
# 7709  Gymnastics  AALTONEN, Paavo Johannes
# 2852    Aquatics     AALTONEN, Arvo Ossian
# 2849    Aquatics     AALTONEN, Arvo Ossian
# 651   Tug of War              AABYE, Edgar
#
# [31165 rows x 2 columns]

# %%
d2=d1.groupby(['Sport','Athlete'])

# %%
d2.size()
# Out:
# Sport      Athlete
# Aquatics   AALTONEN, Arvo Ossian    2
#            ABARCA, Jose Maria       1
#            ABAY-NEMES, Oszkar       1
#            ABDO, Reema              1
#            ABEL, Jennifer           1
#                                    ..
# Wrestling  ZENGIN, Ibrahim          1
#            ZIRKEL, Albert           1
#            ZLATEVA, Stanka          1
#            ZOMBORI, Ã_x0096_dÃ¶n    2
#            ZOZIROV, Zaza            1
# Length: 22875, dtype: int64

# %% [markdown]
# # 8. Which Sport is having most female gold medals?(Top 5)

# %%
d1=pd.DataFrame(data,columns=['Sport','Gender','Medal']).sort_values(by=['Medal','Gender'])

# %%
d1
# Out:
#                Sport Gender   Medal
# 2           Aquatics    Men  Bronze
# 5           Aquatics    Men  Bronze
# 8           Aquatics    Men  Bronze
# 11         Athletics    Men  Bronze
# 12         Athletics    Men  Bronze
# ...              ...    ...     ...
# 31082  Weightlifting  Women  Silver
# 31098      Wrestling  Women  Silver
# 31106      Wrestling  Women  Silver
# 31114      Wrestling  Women  Silver
# 31122      Wrestling  Women  Silver
#
# [31165 rows x 3 columns]

# %%
d2=d1.groupby(['Gender','Sport','Medal'])

# %%
d2.first()
# Out:
# Empty DataFrame
# Columns: []
# ...
